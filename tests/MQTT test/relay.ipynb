# %%
import sys
sys.path.append("../../")

from src import CONFIG, MQTT_RX

conf = CONFIG()


MQTT_RX(conf, role="relay", phase = 1, verbose=1).send_ready_and_wait_for_begin()
# Out:
# [RELAY RX] Publishing 'ready' for phase 1
# [RELAY RX] Connected. Subscribing to 'mkashani/feeds/begin'
# [RELAY RX] Detected Error: source phase mismatch error
# False
