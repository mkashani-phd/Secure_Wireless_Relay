# %%
import sys
sys.path.append("../../")

from src import CONFIG, MQTT_RX

conf = CONFIG()

MQTT_RX(conf, role="destination",phase=2, verbose=1).send_ready_and_wait_for_begin()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.path.append("../../")
# ----> 4 from src import CONFIG, MQTT_RX
#       6 conf = CONFIG()
#       8 MQTT_RX(conf, role="destination",phase=2, verbose=1).send_ready_and_wait_for_begin()
#
# File c:\Users\BLBuh\OneDrive\Documents\Project\Superposing_LDPC\tests\MQTT test\../..\src\__init__.py:1
# ----> 1 from .rx import Demodulation, PostProcessing, RX
#       2 from .tx import TX
#       3 from .config import CONFIG
#
# File c:\Users\BLBuh\OneDrive\Documents\Project\Superposing_LDPC\tests\MQTT test\../..\src\rx.py:13
#       8 import pymongo
#      11 import matplotlib.pyplot as plt
# ---> 13 from . import config
#      14 from . import channelCoding as cc
#      17 class RX:
#
# File c:\Users\BLBuh\OneDrive\Documents\Project\Superposing_LDPC\tests\MQTT test\../..\src\config.py:1
# ----> 1 import yaml
#       2 import numpy as np
#       3 import json
#
# ModuleNotFoundError: No module named 'yaml'
