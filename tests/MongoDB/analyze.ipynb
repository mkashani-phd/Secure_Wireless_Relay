# %%
import pymongo

# Connect to the MongoDB, change the connection string per your MongoDB environment
conn = pymongo.MongoClient("mongodb://10.29.162.146:27017")
db = conn['MAC_1D']
collection_dest_phase1 = db['Destination, phase_1']
collection_dest_phase2 = db['Destination, phase_2']
collection_relay = db['relay, phase_1']

# %%
collection_dest_phase1.count_documents(filter={'integrity':True})
# Out:
# 977

# %%
collection_relay.count_documents(filter={'integrity':True})
# Out:
# 1588

# %%
collection_dest_phase2.count_documents(filter={'integrity':True})
# Out:
# 1037

# %%
collection_dest_phase1.count_documents(filter={'integrity':False})
# Out:
# 269

# %%
collection_relay.count_documents(filter={'integrity':False})
# Out:
# 1

# %%
collection_dest_phase2.count_documents(filter={'integrity':False})
# Out:
# 385

# %%
filter_criteria = {'integrity':True}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_dest_phase1.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 8.132406796013198}]

# %%
filter_criteria = {'integrity':True}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_relay.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 14.358885998689859}]

# %%
filter_criteria = {'integrity':True}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_dest_phase2.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 13.453087570352288}]

# %%
filter_criteria = {'integrity':False}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_dest_phase1.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 7.15222779702963}]

# %%
filter_criteria = {'integrity':False}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_relay.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 14.362520217895508}]

# %%
filter_criteria = {'integrity':False}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_dest_phase2.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 13.186634217299424}]

# %%
filter_criteria = { "$or": [ {"integrity": False}, {"integrity": True} ] }
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_dest_phase1.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 7.920795118062492}]

# %%
filter_criteria = { "$or": [ {"integrity": False}, {"integrity": True} ] }
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_relay.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 14.358888285800749}]

# %%
filter_criteria = { "$or": [ {"integrity": False}, {"integrity": True} ] }
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_dest_phase2.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 13.380946542978622}]
