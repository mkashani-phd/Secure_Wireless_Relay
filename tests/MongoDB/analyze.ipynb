# %%
import pymongo

# Connect to the MongoDB, change the connection string per your MongoDB environment
conn = pymongo.MongoClient("mongodb://10.29.162.146:27017")
db = conn['MAC_SUPERPOSITION']
collection = db['1D_Destination']
db2 = conn['MAC_SUPERPOSITION']
collection_relay = db2['1D_relay']

# %%
collection.count_documents(filter={'integrity':True})
# Out:
# 4716

# %%
collection_relay.count_documents(filter={'integrity':True})
# Out:
# 6149

# %%
collection.count_documents(filter={'integrity':False})
# Out:
# 1700

# %%
collection_relay.count_documents(filter={'integrity':False})
# Out:
# 279

# %%
filter_criteria = {'integrity':True}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 7.744158980803939}]

# %%
filter_criteria = {'integrity':True}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_relay.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 10.06912428632095}]

# %%
filter_criteria = {'integrity':False}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 7.666019359195934}]

# %%
filter_criteria = {'integrity':False}
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_relay.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 10.009379414247356}]

# %%
filter_criteria = { "$or": [ {"integrity": False}, {"integrity": True} ] }
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 7.7234549040063065}]

# %%
filter_criteria = { "$or": [ {"integrity": False}, {"integrity": True} ] }
pipeline = [{"$match": filter_criteria}, {"$group": {"_id":None, "average_value":{"$avg": "$SNR"}}}]
list(collection_relay.aggregate(pipeline))
# Out:
# [{'_id': None, 'average_value': 10.066531128370027}]
