# %%
import sys
sys.path.append("../../..")

from src import CONFIG, MQTT_RX

conf = CONFIG()

MQTT_RX(conf, role="destination",phase=2, verbose=1).send_ready_and_wait_for_begin()
# Out:
# [DESTINATION RX] Publishing 'ready' for phase 2
# [DESTINATION RX] Connected. Subscribing to 'mkashani/feeds/begin'
# [DESTINATION RX] Detected Error: source phase mismatch error
# False
