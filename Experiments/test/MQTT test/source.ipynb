# %%
import sys
sys.path.append("../..")

from src import CONFIG, MQTT_TX

conf = CONFIG()

MQTT_TX(conf, role="source").wait_for_all_ready()
# Out:
# [SOURCE TX] Connected. Subscribing to 'mkashani/feeds/ready'
# [SOURCE TX] Received 'ready' from: relay
# [SOURCE TX] Received 'ready' from: destination
# [SOURCE TX] Sending 'begin'
# [SOURCE TX] All nodes ready
