# %%
import sys
sys.path.append("../../..")

from src import CONFIG, MQTT_TX

conf = CONFIG()

MQTT_TX(conf, role="source", phase=1, verbose=1).wait_for_all_ready()
# Out:
# [SOURCE TX] Connected. Subscribing to 'mkashani/feeds/ready'
# [SOURCE TX] Received 'ready' from relay for phase 1
# [SOURCE TX] Received 'ready' from destination for phase 2, but this node is in phase 1
# [SOURCE TX] Detected Error: source phase mismatch error
# False
