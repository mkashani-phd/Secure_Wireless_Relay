# %%
import paho.mqtt.client as mqtt

import sys
sys.path.append("../..")
from src import CONFIG

conf = CONFIG()

USERNAME = conf.MQTT['AIO_USERNAME']
AIO_KEY = conf.MQTT['AIO_KEY']
BROKER = conf.MQTT['BROKER']
PORT = conf.MQTT['PORT']
TOPIC = f"{USERNAME}/feeds/echo"

client = mqtt.Client()
client.username_pw_set(USERNAME, AIO_KEY)

def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("[✓] Connected — publishing...")
        client.publish(TOPIC, "🚀")
        print("[→] Message sent")
        client.disconnect()
    else:
        print("[!] Connection failed:", rc)

client.on_connect = on_connect
client.connect(BROKER, PORT)
client.loop_forever()
# Out:
# [✓] Connected — publishing...
# [→] Message sent
# /tmp/ipykernel_79077/2141574803.py:15: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# <MQTTErrorCode.MQTT_ERR_CONN_LOST: 7>
