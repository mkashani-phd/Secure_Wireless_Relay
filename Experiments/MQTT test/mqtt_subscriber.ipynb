# %%
import paho.mqtt.client as mqtt
import sys
sys.path.append("../..")
from src import CONFIG

conf = CONFIG()

USERNAME = conf.MQTT['AIO_USERNAME']
AIO_KEY = conf.MQTT['AIO_KEY']
BROKER = conf.MQTT['BROKER']
PORT = conf.MQTT['PORT']
TOPIC = f"{USERNAME}/feeds/echo"

def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("[✓] Subscriber connected")
        client.subscribe(TOPIC)
        print(f"[✓] Subscribed to {TOPIC}")
    else:
        print("[!] Connection failed with code", rc)

def on_message(client, userdata, msg):
    message = msg.payload.decode()
    print(f"[←] Received: {message}")

client = mqtt.Client()
client.username_pw_set(USERNAME, AIO_KEY)
client.on_connect = on_connect
client.on_message = on_message

client.connect(BROKER, PORT)
client.loop_forever()
# Out:
# /tmp/ipykernel_79055/3804775644.py:26: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# [✓] Subscriber connected
# [✓] Subscribed to mkashani/feeds/echo
# [←] Received: 🚀
